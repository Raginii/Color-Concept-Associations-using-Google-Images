# %% [markdown]
# # Analysis III - NEW - (181-186)

# %%
# Initialize these:
typeImg = "top" # photo/ cartoon/ all"
numImg = "50" # 5 or 50
sz = 100
filepath = 'dataTop50.xlsx'
filepath2 = 'dataTop50_181_186.xlsx'

# For spherical
# a=0; b= 30
# # For cylindrical
# a = 30; b =180
# # For categorical
# a = 180; b= 186

strtInd = [0, 2900, 5800, 8700, 11600, 14500, 17400, 20300, 23200, 26100, 29000, 31900, 34800]

# %%
 # Include imports
import glob
from skimage.transform import resize
from skimage.io import imread, imsave, imshow
import os
import pandas as pd
import numpy as np
import skimage.color as skcolor
import matplotlib.pyplot as plt

from sklearn import datasets, linear_model
from sklearn.metrics import mean_squared_error, r2_score
from sklearn import preprocessing

# %%
colNames = ["col_"+str(i) for i in range(58)] 
allConcepts = ['mango','watermelon','honeydew','cantaloupe','grapefruit','strawberry','raspberry','blueberry','avocado','orange','lime','lemon']

# Read data
# Get the color ratings data -From file data_clean.csv
data = pd.read_csv("data_clean.csv",names = colNames)

# Get the LAB coordinates of colors from file LabOrig.csv
#colorData = pd.read_csv("LabOrig.csv",header=None)
colorData = pd.read_csv("Lab.csv",header=None)
colorDataRGB = pd.read_csv("RGB.csv",header=None)
path = "E:/GitRepo/Color-Concept-Associaitons-using-Google-Images/downloads"
sz = 100

# %%
df = pd.read_excel(filepath)
Q = df.as_matrix()
Q.shape
# Out:
# (34800, 187)

# %%
df2 = pd.read_excel(filepath2,header=None)
Q2_init = df2.as_matrix()
Q2_init.shape
# Out:
# (34800, 6)

# %%
from sklearn.preprocessing import StandardScaler
Q2_scalar = StandardScaler()
Q2 = Q2_scalar.fit_transform(Q2_init)

# %%
# Q2 = preprocessing.normalize(Q2_init)
# print(Q2.shape)

# %% [markdown]
# # Spherical + Cylindrical + Categorical

# %%
X = np.column_stack([Q[:,:-1],Q2[:,:]])
y = np.copy(Q[:,-1])
print(X.shape)

# from sklearn.preprocessing import StandardScaler
# X_scalar = StandardScaler()
# X = X_scalar.fit_transform(Xt)
# Out:
# (34800, 192)

# %%
# y_scalar = StandardScaler()
# y = y_scalar.fit_transform(yt[:, None])[:, 0]
# y.shape

# %%
xNew = np.column_stack([X,y])
print(xNew.shape)
xTemp = np.copy(xNew)
# Out:
# (34800, 193)

# %%
xNew.shape
# Out:
# (34800, 193)

# %%
alpha = np.logspace(-3,-1,10, endpoint=True)
plt.plot(alpha,'g.-')
plt.show()
print(alpha)
errorTrainAlpha = np.zeros((12,len(alpha)))  # Saves error values across different alpha values for all fruits
errorTestAlpha = np.zeros((12,len(alpha)))  # Saves error values across different alpha values for all fruits


ftTrainDict = {}
ftTestDict = {}
# Linear Regression using Cross Validation
# Leave one out cross validation -- strtInd holds the starting indices of set of fruit data 
plt.close('all')

fig1,ax1 = plt.subplots(4,3,figsize=(25,20))
#fig2,ax2 = plt.subplots(4,3,figsize=(25,20))
p = 0
q = 0
for i in range(len(strtInd)-1):
    numFt = []
    trainErrFt = []
    testErrFt = []
    trDict = {}
    teDict = {}
    
    # Leave one entire fruit group
    testFruit =  allConcepts[i]
    print("\nLeaving out fruit group : ",allConcepts[i])
    testTemp = np.copy(xTemp[strtInd[i]:strtInd[i+1],:]) # Get all rows from the LOO group
    trainTemp = np.delete(xTemp,range(strtInd[i],strtInd[i+1]),0)
    
    #trainTemp = np.copy(xTemp)
    #np.random.shuffle(trainTemp)
    row = len(trainTemp)
    
    #Training set
    X_train = np.column_stack([np.ones((row,1)), trainTemp[:,:-1]]) # add offset
    y_train = np.copy(trainTemp[:,-1])
    # Test set (hold out set)
    row2 = len(testTemp)
    X_test  = np.column_stack([np.ones((row2,1)), testTemp[:,:-1]]) #xTemp[row:tot,0:3]#
    y_test  = np.copy(testTemp[:,-1])
    #print(X_train.shape, y_train.shape,X_test.shape, y_test.shape )
    # Before Lasso --> do a LinearRegression to compute error using all 58
    ct = 0
    for m,a in enumerate(alpha):
        print("\n\n---------------- For alpha value : ",a," -------------")
        # Create linear regression object
        #regr = linear_model.LinearRegression(fit_intercept=False)
        regr = linear_model.Lasso(alpha = a,fit_intercept=False,copy_X = True, max_iter=3000)
        #print(regr)
        # Train the model using the training sets
        regr.fit(X_train, y_train)
        
        # Make predictions using the testing set
        y_pred = regr.predict(X_test)
        ytrain_pred = regr.predict(X_train)
        
        ft = np.count_nonzero(regr.coef_)
        print("Non zero features: ",ft-1 )
        numFt.append(ft)
        if ct ==0 or ft == 4:
            print("The top features are: ")
            print("Sparse Coefficients: \n",regr.sparse_coef_)
            #ct = 1
#         print("Score is : %.2f" % regr.score(X_test, y_test))
#         # The coefficients
#         print('Coefficients: ', regr.coef_)
        #print("Sparse Coefficients: \n",regr.sparse_coef_)
#         #print('Intercept: \n', regr.intercept_)
#         # The mean squared error
#         print("\nMean squared error: %.4f"
#               % mean_squared_error(y_test, y_pred))
#         # Explained variance score: 1 is perfect prediction
#         print('Variance score: %.2f' % r2_score(y_test, y_pred))
        
        trainErr = mean_squared_error(y_train, ytrain_pred)
        testErr  =  mean_squared_error(y_test, y_pred)
        # Save the avg error vs alpha
        errorTrainAlpha[i,m] = trainErr
        errorTestAlpha[i,m] = testErr
        
        trDict[ft] = trainErr
        teDict[ft] = testErr
        #print(trainErr, testErr)
        
        ## local error wrt the alpha
        trainErrFt.append(trainErr)
        testErrFt.append(testErr)
        ############## For test purposes - Average prediction over all Images of LOO group ############
        totalTestImages = y_pred.size/58  #58N rows -> every image has 58 rows of data
        avg_pred = [np.sum([y_pred[p] for p in range(q,y_pred.size,58)])/totalTestImages for q in range(58)]
    print(numFt)   
    for key in sorted(trDict.keys()):
        if key in ftTrainDict:
            ftTrainDict[key].append(trDict[key])
            ftTestDict[key].append(teDict[key])
        else:
            ftTrainDict[key] = [trDict[key]]
            ftTestDict[key] = [teDict[key]]
    ax1[p,q].plot(numFt,trainErrFt,'g.-',numFt, testErrFt,'r.-')
    ax1[p,q].set_title(testFruit)
    ax1[p,q].set_xticks(numFt)
    ax1[p,q].set_label(['Training','Test'])
    
    
    q += 1
    if q == 3:
        p += 1
        q = 0
plt.show()
plt.close('all')
# Out:
# [0.001      0.0016681  0.00278256 0.00464159 0.00774264 0.0129155
#  0.02154435 0.03593814 0.05994843 0.1       ]
#
# Leaving out fruit group :  mango
#
#
# ---------------- For alpha value :  0.001  -------------
# Non zero features:  6
# The top features are:
# Sparse Coefficients:
#    (0, 0)	0.1433526155184325
#   (0, 25)	-0.015473925045389785
#   (0, 55)	0.15851078082966413
#   (0, 180)	0.07860369887437321
#   (0, 181)	0.1905230182273522
#   (0, 186)	0.101904450625031
#   (0, 188)	0.007628663655944339
#
#
# ---------------- For alpha value :  0.0016681005372000592  -------------
# Non zero features:  5
# The top features are:
# Sparse Coefficients:
#    (0, 0)	0.14593028001456979
#   (0, 55)	0.15109441603754561
#   (0, 180)	0.07261368519991113
#   (0, 181)	0.1717707847525939
#   (0, 186)	0.09121806461854476
#   (0, 188)	0.012578484927638427
#
#
# ---------------- For alpha value :  0.0027825594022071257  -------------
# Non zero features:  6
# The top features are:
# Sparse Coefficients:
#    (0, 0)	0.1531247691099054
#   (0, 55)	0.14321745945322395
#   (0, 180)	0.06591528889697629
#   (0, 181)	0.13070935951636675
#   (0, 186)	0.0792028256074654
#   (0, 187)	0.006586765751424958
#   (0, 188)	0.016398790927892353
#
#
# ---------------- For alpha value :  0.004641588833612777  -------------
# Non zero features:  6
# The top features are:
# Sparse Coefficients:
#    (0, 0)	0.165348041688428
#   (0, 55)	0.12935267958775193
#   (0, 180)	0.054893809271724006
#   (0, 181)	0.05656041190073759
#   (0, 186)	0.06335909284665088
#   (0, 187)	0.022947040671180547
#   (0, 188)	0.017876385358894947
#
#
# ---------------- For alpha value :  0.007742636826811269  -------------
# Non zero features:  4
# The top features are:
# Sparse Coefficients:
#    (0, 0)	0.18299511043556968
#   (0, 55)	0.09361740885961445
#   (0, 180)	0.0489612821331194
#   (0, 187)	0.040040299473467884
#   (0, 188)	0.025083335429436627
#
#
# ---------------- For alpha value :  0.01291549665014884  -------------
# Non zero features:  4
# The top features are:
# Sparse Coefficients:
#    (0, 0)	0.19366519882774452
#   (0, 55)	0.058723062745385954
#   (0, 180)	0.003385670904113565
#   (0, 187)	0.048497290211852936
#   (0, 188)	0.02527758823634949
#
#
# ---------------- For alpha value :  0.021544346900318832  -------------
# Non zero features:  2
# The top features are:
# Sparse Coefficients:
#    (0, 0)	0.1972253731441744
#   (0, 187)	0.05677115727408968
#   (0, 188)	0.019365014996622108
#
#
# ---------------- For alpha value :  0.03593813663804626  -------------
# Non zero features:  2
# The top features are:
# Sparse Coefficients:
#    (0, 0)	0.1829256359186008
#   (0, 187)	0.0491798837151373
#   (0, 188)	0.012749753177297391
#
#
# ---------------- For alpha value :  0.05994842503189409  -------------
# Non zero features:  2
# The top features are:
# Sparse Coefficients:
#    (0, 0)	0.15907223859196457
#   (0, 187)	0.036511277148889555
#   (0, 188)	0.001720321032641462
#
#
# ---------------- For alpha value :  0.1  -------------
# Non zero features:  0
# The top features are:
# Sparse Coefficients:
#    (0, 0)	0.11927732787304074
# [7, 6, 7, 7, 5, 5, 3, 3, 3, 1]
#
# Leaving out fruit group :  watermelon
#
#
# ---------------- For alpha value :  0.001  -------------
# Non zero features:  7
# The top features are:
# Sparse Coefficients:
#    (0, 0)	0.1415941579259209
#   (0, 25)	-0.0077092692225192785
#   (0, 55)	0.16670020475204675
#   (0, 180)	0.0876102008126642
#   (0, 181)	0.15504560653085014
#   (0, 186)	0.0881867138274165
#   (0, 188)	0.023522693616410503
#   (0, 191)	-0.006790871846301348
#
#
# ---------------- For alpha value :  0.0016681005372000592  -------------
# Non zero features:  6
# The top features are:
# Sparse Coefficients:
#    (0, 0)	0.14507635009969372
#   (0, 55)	0.16034473160688498
#   (0, 180)	0.08408694739535731
#   (0, 181)	0.12803968087005554
#   (0, 186)	0.0820680780370641
#   (0, 187)	0.014476914541674796
#   (0, 188)	0.009016859269451713
#
#
# ---------------- For alpha value :  0.0027825594022071257  -------------
# Non zero features:  6
# The top features are:
# Sparse Coefficients:
#    (0, 0)	0.15255161713901477
#   (0, 55)	0.1529144817414437
#   (0, 180)	0.07746863555513465
#   (0, 181)	0.08092488539167944
#   (0, 186)	0.07218138268957289
#   (0, 187)	0.024663270854869173
#   (0, 188)	0.009926176325018776
#
#
# ---------------- For alpha value :  0.004641588833612777  -------------
# Non zero features:  6
# The top features are:
# Sparse Coefficients:
#    (0, 0)	0.16501745666622222
#   (0, 55)	0.14060551073466848
#   (0, 180)	0.06635456901662867
#   (0, 181)	0.0023315864133481275
#   (0, 186)	0.05570411763722188
#   (0, 187)	0.0415978265597516
#   (0, 188)	0.011494617321153706
#
#
# ---------------- For alpha value :  0.007742636826811269  -------------
# Non zero features:  4
# The top features are:
# Sparse Coefficients:
#    (0, 0)	0.17661572955413438
#   (0, 55)	0.1068897211543132
#   (0, 180)	0.05762229378067113
#   (0, 187)	0.04894689049696529
#   (0, 188)	0.01805955933337808
#
#
# ---------------- For alpha value :  0.01291549665014884  -------------
# Non zero features:  4
# The top features are:
# Sparse Coefficients:
#    (0, 0)	0.18695841232930757
#   (0, 55)	0.0750918391719132
#   (0, 180)	0.011673948204178563
#   (0, 187)	0.057110010469864816
#   (0, 188)	0.01837824055180115
#
#
# ---------------- For alpha value :  0.021544346900318832  -------------
# Non zero features:  2
# The top features are:
# Sparse Coefficients:
#    (0, 0)	0.19553233307377965
#   (0, 187)	0.06990394777325809
#   (0, 188)	0.012479856605500472
#
#
# ---------------- For alpha value :  0.03593813663804626  -------------
# Non zero features:  2
# The top features are:
# Sparse Coefficients:
#    (0, 0)	0.18100741448834534
#   (0, 187)	0.0635082161506463
#   (0, 188)	0.0042094418050568905
#
#
# ---------------- For alpha value :  0.05994842503189409  -------------
# Non zero features:  1
# The top features are:
# Sparse Coefficients:
#    (0, 0)	0.15679360814294882
#   (0, 187)	0.0434245514614582
#
#
# ---------------- For alpha value :  0.1  -------------
# Non zero features:  1
# The top features are:
# Sparse Coefficients:
#    (0, 0)	0.1164139617387237
#   (0, 187)	0.0030665092657414027
# [8, 7, 7, 7, 5, 5, 3, 3, 2, 2]
#
# Leaving out fruit group :  honeydew
#
#
# ---------------- For alpha value :  0.001  -------------
# Non zero features:  7
# The top features are:
# Sparse Coefficients:
#    (0, 0)	0.14241321893843342
#   (0, 25)	-0.01478910314518237
#   (0, 55)	0.17099536620653064
#   (0, 180)	0.0817993528048063
#   (0, 181)	0.20359445706442783
#   (0, 186)	0.08573336300770694
#   (0, 188)	0.009903676525291612
#   (0, 191)	-0.0013133127537822845
#
#
# ---------------- For alpha value :  0.0016681005372000592  -------------
# Non zero features:  6
# The top features are:
# Sparse Coefficients:
#    (0, 0)	0.14530488412803355
#   (0, 55)	0.16381615404046215
#   (0, 180)	0.07570032343443592
#   (0, 181)	0.1802118060193664
#   (0, 186)	0.07716778377759353
#   (0, 187)	0.005621902354451044
#   (0, 188)	0.008592050283798563
#
#
# ---------------- For alpha value :  0.0027825594022071257  -------------
# Non zero features:  6
# The top features are:
# Sparse Coefficients:
#    (0, 0)	0.15282571318863755
#   (0, 55)	0.15590709210405723
#   (0, 180)	0.06858939942393533
#   (0, 181)	0.13489026732781395
#   (0, 186)	0.06647912624002604
#   (0, 187)	0.01540883705697903
#   (0, 188)	0.00976633446139713
#
#
# ---------------- For alpha value :  0.004641588833612777  -------------
# Non zero features:  6
# The top features are:
# Sparse Coefficients:
#    (0, 0)	0.1653647085653528
#   (0, 55)	0.14286958126793387
#   (0, 180)	0.05659161077487483
#   (0, 181)	0.05928688778608054
#   (0, 186)	0.0486754097113351
#   (0, 187)	0.03163269560166741
#   (0, 188)	0.011817014108748731
#
#
# ---------------- For alpha value :  0.007742636826811269  -------------
# Non zero features:  4
# The top features are:
# Sparse Coefficients:
#    (0, 0)	0.18189841787573843
#   (0, 55)	0.11376375338977429
#   (0, 180)	0.042626302018220166
#   (0, 187)	0.04782294974329626
#   (0, 188)	0.017985759618378696
#
#
# ---------------- For alpha value :  0.01291549665014884  -------------
# Non zero features:  3
# The top features are:
# Sparse Coefficients:
#    (0, 0)	0.19262158622781048
#   (0, 55)	0.07596895169357182
#   (0, 187)	0.0558301926665149
#   (0, 188)	0.01867780698329326
#
#
# ---------------- For alpha value :  0.021544346900318832  -------------
# Non zero features:  2
# The top features are:
# Sparse Coefficients:
#    (0, 0)	0.1989470434939895
#   (0, 187)	0.06709265388141536
#   (0, 188)	0.012221707335986504
#
#
# ---------------- For alpha value :  0.03593813663804626  -------------
# Non zero features:  2
# The top features are:
# Sparse Coefficients:
#    (0, 0)	0.18450776804097788
#   (0, 187)	0.05993783385306938
#   (0, 188)	0.004859772513823665
#
#
# ---------------- For alpha value :  0.05994842503189409  -------------
# Non zero features:  1
# The top features are:
# Sparse Coefficients:
#    (0, 0)	0.16041823262254684
#   (0, 187)	0.040712545748355346
#
#
# ---------------- For alpha value :  0.1  -------------
# Non zero features:  1
# The top features are:
# Sparse Coefficients:
#    (0, 0)	0.12023096822050251
#   (0, 187)	0.0007255174738757537
# [8, 7, 7, 7, 5, 4, 3, 3, 2, 2]
#
# Leaving out fruit group :  cantaloupe
#
#
# ---------------- For alpha value :  0.001  -------------
# Non zero features:  6
# The top features are:
# Sparse Coefficients:
#    (0, 0)	0.143465608101745
#   (0, 25)	-0.020721719663817535
#   (0, 55)	0.17312141423289595
#   (0, 180)	0.07004749091682395
#   (0, 181)	0.17926291327866348
#   (0, 186)	0.10545547908044757
#   (0, 188)	0.008212018733888648
#
#
# ---------------- For alpha value :  0.0016681005372000592  -------------
# Non zero features:  5
# The top features are:
# Sparse Coefficients:
#    (0, 0)	0.14549243817028196
#   (0, 55)	0.16566328366967475
#   (0, 180)	0.06283673203469577
#   (0, 181)	0.16034235827317775
#   (0, 186)	0.09513680700538707
#   (0, 188)	0.012798179103602774
#
#
# ---------------- For alpha value :  0.0027825594022071257  -------------
# Non zero features:  6
# The top features are:
# Sparse Coefficients:
#    (0, 0)	0.1527456186367617
#   (0, 55)	0.15795532478882315
#   (0, 180)	0.05571940587792742
#   (0, 181)	0.11693138091566403
#   (0, 186)	0.08501496987446305
#   (0, 187)	0.008662772292430477
#   (0, 188)	0.0146809523275367
#
#
# ---------------- For alpha value :  0.004641588833612777  -------------
# Non zero features:  6
# The top features are:
# Sparse Coefficients:
#    (0, 0)	0.1648973818146977
#   (0, 55)	0.14496467045335654
#   (0, 180)	0.04384664738875516
#   (0, 181)	0.043135520202897425
#   (0, 186)	0.06916508398610424
#   (0, 187)	0.024438399835832385
#   (0, 188)	0.0166113144962859
#
#
# ---------------- For alpha value :  0.007742636826811269  -------------
# Non zero features:  4
# The top features are:
# Sparse Coefficients:
#    (0, 0)	0.1818158432392918
#   (0, 55)	0.10866760551387404
#   (0, 180)	0.03827771046515886
#   (0, 187)	0.03870994415761835
#   (0, 188)	0.025246486475593098
#
#
# ---------------- For alpha value :  0.01291549665014884  -------------
# Non zero features:  3
# The top features are:
# Sparse Coefficients:
#    (0, 0)	0.1925268505296113
#   (0, 55)	0.06637770332075575
#   (0, 187)	0.04768537995321793
#   (0, 188)	0.02508739815605075
#
#
# ---------------- For alpha value :  0.021544346900318832  -------------
# Non zero features:  2
# The top features are:
# Sparse Coefficients:
#    (0, 0)	0.19695968415975526
#   (0, 187)	0.0569061817552126
#   (0, 188)	0.01909030391728447
#
#
# ---------------- For alpha value :  0.03593813663804626  -------------
# Non zero features:  2
# The top features are:
# Sparse Coefficients:
#    (0, 0)	0.18267129004672064
#   (0, 187)	0.04903353469300666
#   (0, 188)	0.012763490281139695
#
#
# ---------------- For alpha value :  0.05994842503189409  -------------
# Non zero features:  2
# The top features are:
# Sparse Coefficients:
#    (0, 0)	0.1588368121371281
#   (0, 187)	0.03590102874457106
#   (0, 188)	0.0022098653832411173
#
#
# ---------------- For alpha value :  0.1  -------------
# Non zero features:  0
# The top features are:
# Sparse Coefficients:
#    (0, 0)	0.11906442295924766
# [7, 6, 7, 7, 5, 4, 3, 3, 3, 1]
#
# Leaving out fruit group :  grapefruit
#
#
# ---------------- For alpha value :  0.001  -------------
# Non zero features:  7
# The top features are:
# Sparse Coefficients:
#    (0, 0)	0.14044378436926902
#   (0, 25)	-0.01653094215120959
#   (0, 55)	0.17376062308981483
#   (0, 180)	0.07221602756532812
#   (0, 181)	0.18577993793494504
#   (0, 186)	0.1059301344934063
#   (0, 188)	0.009471225078669883
#   (0, 191)	-0.0010000721313170927
#
#
# ---------------- For alpha value :  0.0016681005372000592  -------------
# Non zero features:  6
# The top features are:
# Sparse Coefficients:
#    (0, 0)	0.14302000393325212
#   (0, 55)	0.1668688521258434
#   (0, 180)	0.06550131769852646
#   (0, 181)	0.16321786452238377
#   (0, 186)	0.09784796563291001
#   (0, 187)	0.004259252391184615
#   (0, 188)	0.00954471851239891
#
#
# ---------------- For alpha value :  0.0027825594022071257  -------------
# Non zero features:  6
# The top features are:
# Sparse Coefficients:
#    (0, 0)	0.1504348708126355
#   (0, 55)	0.15907101543339613
#   (0, 180)	0.05852536717259561
#   (0, 181)	0.11786896154874993
#   (0, 186)	0.0883015739035549
#   (0, 187)	0.014366841616326063
#   (0, 188)	0.010400648840260786
#
#
# ---------------- For alpha value :  0.004641588833612777  -------------
# Non zero features:  6
# The top features are:
# Sparse Coefficients:
#    (0, 0)	0.16279483215916618
#   (0, 55)	0.14619213938618922
#   (0, 180)	0.046783068900138766
#   (0, 181)	0.042302118929292275
#   (0, 186)	0.07234113932452224
#   (0, 187)	0.031090533399254563
#   (0, 188)	0.011950040511266392
#
#
# ---------------- For alpha value :  0.007742636826811269  -------------
# Non zero features:  4
# The top features are:
# Sparse Coefficients:
#    (0, 0)	0.17991297896943076
#   (0, 55)	0.10877915702775184
#   (0, 180)	0.043056425755946745
#   (0, 187)	0.046309322990977383
#   (0, 188)	0.02019342388750897
#
#
# ---------------- For alpha value :  0.01291549665014884  -------------
# Non zero features:  3
# The top features are:
# Sparse Coefficients:
#    (0, 0)	0.19023420132800653
#   (0, 55)	0.07310560331258466
#   (0, 187)	0.054946612384498425
#   (0, 188)	0.019977917385737256
#
#
# ---------------- For alpha value :  0.021544346900318832  -------------
# Non zero features:  2
# The top features are:
# Sparse Coefficients:
#    (0, 0)	0.19595900172044817
#   (0, 187)	0.0661386638159302
#   (0, 188)	0.013163496713154777
#
#
# ---------------- For alpha value :  0.03593813663804626  -------------
# Non zero features:  2
# The top features are:
# Sparse Coefficients:
#    (0, 0)	0.18167732637550932
#   (0, 187)	0.058205186121519197
#   (0, 188)	0.0067827820985738385
#
#
# ---------------- For alpha value :  0.05994842503189409  -------------
# Non zero features:  1
# The top features are:
# Sparse Coefficients:
#    (0, 0)	0.15785182435370504
#   (0, 187)	0.04116288987133201
#
#
# ---------------- For alpha value :  0.1  -------------
# Non zero features:  1
# The top features are:
# Sparse Coefficients:
#    (0, 0)	0.11810142901005607
#   (0, 187)	0.001645507958383843
# [8, 7, 7, 7, 5, 4, 3, 3, 2, 2]
#
# Leaving out fruit group :  strawberry
#
#
# ---------------- For alpha value :  0.001  -------------
# Non zero features:  8
# The top features are:
# Sparse Coefficients:
#    (0, 0)	0.14469104265431898
#   (0, 25)	-0.01171525305585476
#   (0, 55)	0.17017471764613112
#   (0, 180)	0.08223729870978261
#   (0, 181)	0.1392157091442662
#   (0, 186)	0.10396226849938267
#   (0, 187)	0.0014640811197862051
#   (0, 188)	0.016845814636098362
#   (0, 191)	-0.0009252745469825033
#
#
# ---------------- For alpha value :  0.0016681005372000592  -------------
# Non zero features:  6
# The top features are:
# Sparse Coefficients:
#    (0, 0)	0.14812265349706116
#   (0, 55)	0.162473590377017
#   (0, 180)	0.07729182873755056
#   (0, 181)	0.10984061696214083
#   (0, 186)	0.09946532286448602
#   (0, 187)	0.010967496304993225
#   (0, 188)	0.012788898364415437
#
#
# ---------------- For alpha value :  0.0027825594022071257  -------------
# Non zero features:  6
# The top features are:
# Sparse Coefficients:
#    (0, 0)	0.1557037362928324
#   (0, 55)	0.15455267998628844
#   (0, 180)	0.07060562869025355
#   (0, 181)	0.06279027288607521
#   (0, 186)	0.08950160997886167
#   (0, 187)	0.02107136644758502
#   (0, 188)	0.013973557654364694
#
#
# ---------------- For alpha value :  0.004641588833612777  -------------
# Non zero features:  5
# The top features are:
# Sparse Coefficients:
#    (0, 0)	0.16803177194926644
#   (0, 55)	0.13735508008392916
#   (0, 180)	0.06367516915557749
#   (0, 186)	0.0607376964559026
#   (0, 187)	0.03579269734311251
#   (0, 188)	0.017322422274582014
#
#
# ---------------- For alpha value :  0.007742636826811269  -------------
# Non zero features:  4
# The top features are:
# Sparse Coefficients:
#    (0, 0)	0.1799864246580349
#   (0, 55)	0.10189511349473841
#   (0, 180)	0.05607590039343919
#   (0, 187)	0.04237071628557007
#   (0, 188)	0.02523887833089802
#
#
# ---------------- For alpha value :  0.01291549665014884  -------------
# Non zero features:  4
# The top features are:
# Sparse Coefficients:
#    (0, 0)	0.19037806098312654
#   (0, 55)	0.06951139578595233
#   (0, 180)	0.009689477106876553
#   (0, 187)	0.050134001894826426
#   (0, 188)	0.02609112411805487
#
#
# ---------------- For alpha value :  0.021544346900318832  -------------
# Non zero features:  2
# The top features are:
# Sparse Coefficients:
#    (0, 0)	0.1973703551344891
#   (0, 187)	0.06121633141750695
#   (0, 188)	0.02069872846307326
#
#
# ---------------- For alpha value :  0.03593813663804626  -------------
# Non zero features:  2
# The top features are:
# Sparse Coefficients:
#    (0, 0)	0.1831032298088808
#   (0, 187)	0.05463863671840598
#   (0, 188)	0.013462353883200022
#
#
# ---------------- For alpha value :  0.05994842503189409  -------------
# Non zero features:  2
# The top features are:
# Sparse Coefficients:
#    (0, 0)	0.1593042210182654
#   (0, 187)	0.04367385058100624
#   (0, 188)	0.0013840163972854325
#
#
# ---------------- For alpha value :  0.1  -------------
# Non zero features:  1
# The top features are:
# Sparse Coefficients:
#    (0, 0)	0.11962181396780106
#   (0, 187)	0.00693894007473022
# [9, 7, 7, 6, 5, 5, 3, 3, 3, 2]
#
# Leaving out fruit group :  raspberry
#
#
# ---------------- For alpha value :  0.001  -------------
# Non zero features:  7
# The top features are:
# Sparse Coefficients:
#    (0, 0)	0.13859685378579814
#   (0, 25)	-0.003257598538786503
#   (0, 55)	0.1723778846931086
#   (0, 180)	0.08154022555675179
#   (0, 181)	0.17869747089137084
#   (0, 186)	0.11321408082268491
#   (0, 188)	0.010108528588207114
#   (0, 191)	-0.0014359769244772743
#
#
# ---------------- For alpha value :  0.0016681005372000592  -------------
# Non zero features:  6
# The top features are:
# Sparse Coefficients:
#    (0, 0)	0.14317108099275488
#   (0, 55)	0.16698857429933683
#   (0, 180)	0.07662956983821377
#   (0, 181)	0.15037331018838002
#   (0, 186)	0.10528395287261073
#   (0, 187)	0.005916527418939836
#   (0, 188)	0.0100394785593018
#
#
# ---------------- For alpha value :  0.0027825594022071257  -------------
# Non zero features:  6
# The top features are:
# Sparse Coefficients:
#    (0, 0)	0.1517004080548523
#   (0, 55)	0.15755318396129825
#   (0, 180)	0.06956755462934523
#   (0, 181)	0.09821332445882693
#   (0, 186)	0.09485796423066657
#   (0, 187)	0.017407500365213404
#   (0, 188)	0.011336335294949554
#
#
# ---------------- For alpha value :  0.004641588833612777  -------------
# Non zero features:  6
# The top features are:
# Sparse Coefficients:
#    (0, 0)	0.16592759410522429
#   (0, 55)	0.14185693145256645
#   (0, 180)	0.05774792133337328
#   (0, 181)	0.011170933530775804
#   (0, 186)	0.07749781090682074
#   (0, 187)	0.036569350077813416
#   (0, 188)	0.013505631473721712
#
#
# ---------------- For alpha value :  0.007742636826811269  -------------
# Non zero features:  4
# The top features are:
# Sparse Coefficients:
#    (0, 0)	0.18128617979162803
#   (0, 55)	0.09983722103124201
#   (0, 180)	0.05462191811794833
#   (0, 187)	0.04652813760409312
#   (0, 188)	0.023536053488436272
#
#
# ---------------- For alpha value :  0.01291549665014884  -------------
# Non zero features:  4
# The top features are:
# Sparse Coefficients:
#    (0, 0)	0.19231188139782368
#   (0, 55)	0.06567681938332569
#   (0, 180)	0.007689097714711082
#   (0, 187)	0.05534384368849443
#   (0, 188)	0.02417882374791314
#
#
# ---------------- For alpha value :  0.021544346900318832  -------------
# Non zero features:  2
# The top features are:
# Sparse Coefficients:
#    (0, 0)	0.19829075802338955
#   (0, 187)	0.06598564217892458
#   (0, 188)	0.018586173406985394
#
#
# ---------------- For alpha value :  0.03593813663804626  -------------
# Non zero features:  2
# The top features are:
# Sparse Coefficients:
#    (0, 0)	0.1839769059521566
#   (0, 187)	0.05843099957728541
#   (0, 188)	0.012237625228012139
#
#
# ---------------- For alpha value :  0.05994842503189409  -------------
# Non zero features:  2
# The top features are:
# Sparse Coefficients:
#    (0, 0)	0.16009995880985267
#   (0, 187)	0.04581493011683927
#   (0, 188)	0.0016615087181224826
#
#
# ---------------- For alpha value :  0.1  -------------
# Non zero features:  1
# The top features are:
# Sparse Coefficients:
#    (0, 0)	0.12026454572864019
#   (0, 187)	0.009043710460565943
# [8, 7, 7, 7, 5, 5, 3, 3, 3, 2]
#
# Leaving out fruit group :  blueberry
#
#
# ---------------- For alpha value :  0.001  -------------
# Non zero features:  8
# The top features are:
# Sparse Coefficients:
#    (0, 0)	0.1418191798328597
#   (0, 25)	-0.006908693761413175
#   (0, 55)	0.17464359189310139
#   (0, 80)	0.0011746639476708618
#   (0, 180)	0.09292199164116022
#   (0, 181)	0.16381955124304085
#   (0, 186)	0.07144030094089354
#   (0, 188)	0.01104988017114758
#   (0, 191)	-0.0009620815762201893
#
#
# ---------------- For alpha value :  0.0016681005372000592  -------------
# Non zero features:  5
# The top features are:
# Sparse Coefficients:
#    (0, 0)	0.14530697619263122
#   (0, 55)	0.1716293640952209
#   (0, 180)	0.08795879919283225
#   (0, 181)	0.1421092425064235
#   (0, 186)	0.05952011547951062
#   (0, 188)	0.015910876433146533
#
#
# ---------------- For alpha value :  0.0027825594022071257  -------------
# Non zero features:  6
# The top features are:
# Sparse Coefficients:
#    (0, 0)	0.15248853660008185
#   (0, 55)	0.16574097322677794
#   (0, 180)	0.08159650671117613
#   (0, 181)	0.1013600395538845
#   (0, 186)	0.04211191689749524
#   (0, 187)	0.0023606486857409405
#   (0, 188)	0.024182178800074144
#
#
# ---------------- For alpha value :  0.004641588833612777  -------------
# Non zero features:  6
# The top features are:
# Sparse Coefficients:
#    (0, 0)	0.16505138532922262
#   (0, 55)	0.1540908275678443
#   (0, 180)	0.07139722475526376
#   (0, 181)	0.019893737893433763
#   (0, 186)	0.022763140021842976
#   (0, 187)	0.01944992154191229
#   (0, 188)	0.02601915514427215
#
#
# ---------------- For alpha value :  0.007742636826811269  -------------
# Non zero features:  4
# The top features are:
# Sparse Coefficients:
#    (0, 0)	0.17517505593845847
#   (0, 55)	0.1311415471967716
#   (0, 180)	0.05097231355602163
#   (0, 187)	0.028742370329543573
#   (0, 188)	0.028401429579750084
#
#
# ---------------- For alpha value :  0.01291549665014884  -------------
# Non zero features:  4
# The top features are:
# Sparse Coefficients:
#    (0, 0)	0.1858548813949124
#   (0, 55)	0.101022580993816
#   (0, 180)	0.0039499766653244206
#   (0, 187)	0.037280084722980104
#   (0, 188)	0.028446543026615468
#
#
# ---------------- For alpha value :  0.021544346900318832  -------------
# Non zero features:  2
# The top features are:
# Sparse Coefficients:
#    (0, 0)	0.19870629891211403
#   (0, 187)	0.05543819164393271
#   (0, 188)	0.02084947429603795
#
#
# ---------------- For alpha value :  0.03593813663804626  -------------
# Non zero features:  2
# The top features are:
# Sparse Coefficients:
#    (0, 0)	0.1842184350654003
#   (0, 187)	0.048146555756713824
#   (0, 188)	0.013642074383723954
#
#
# ---------------- For alpha value :  0.05994842503189409  -------------
# Non zero features:  2
# The top features are:
# Sparse Coefficients:
#    (0, 0)	0.16005121974443043
#   (0, 187)	0.03597622857338472
#   (0, 188)	0.0016264242655315761
#
#
# ---------------- For alpha value :  0.1  -------------
# Non zero features:  0
# The top features are:
# Sparse Coefficients:
#    (0, 0)	0.11975335248589333
# [9, 6, 7, 7, 5, 5, 3, 3, 3, 1]
#
# Leaving out fruit group :  avocado
#
#
# ---------------- For alpha value :  0.001  -------------
# Non zero features:  7
# The top features are:
# Sparse Coefficients:
#    (0, 0)	0.1422954509579504
#   (0, 25)	-0.005572383313461978
#   (0, 55)	0.17769061147681836
#   (0, 180)	0.07976315618626446
#   (0, 181)	0.22886074027976258
#   (0, 186)	0.05144651338504201
#   (0, 187)	0.0004957967826947342
#   (0, 188)	0.0037203954883837935
#
#
# ---------------- For alpha value :  0.0016681005372000592  -------------
# Non zero features:  6
# The top features are:
# Sparse Coefficients:
#    (0, 0)	0.14615361963242476
#   (0, 55)	0.17197416725086
#   (0, 180)	0.07506978914347431
#   (0, 181)	0.20214563476056685
#   (0, 186)	0.04559128445509926
#   (0, 187)	0.0069649478656673295
#   (0, 188)	0.0033853637077515828
#
#
# ---------------- For alpha value :  0.0027825594022071257  -------------
# Non zero features:  6
# The top features are:
# Sparse Coefficients:
#    (0, 0)	0.153485912194245
#   (0, 55)	0.16418855790682527
#   (0, 180)	0.06852356923558063
#   (0, 181)	0.15756258804352158
#   (0, 186)	0.03538143179813443
#   (0, 187)	0.016817636724082447
#   (0, 188)	0.004254224028762466
#
#
# ---------------- For alpha value :  0.004641588833612777  -------------
# Non zero features:  6
# The top features are:
# Sparse Coefficients:
#    (0, 0)	0.1657049200773337
#   (0, 55)	0.15126223135024694
#   (0, 180)	0.057569359550063266
#   (0, 181)	0.08344764017335081
#   (0, 186)	0.018174186319616852
#   (0, 187)	0.03303869905299799
#   (0, 188)	0.005894886141788383
#
#
# ---------------- For alpha value :  0.007742636826811269  -------------
# Non zero features:  4
# The top features are:
# Sparse Coefficients:
#    (0, 0)	0.18139304593716893
#   (0, 55)	0.1309476772387045
#   (0, 180)	0.03565251975095977
#   (0, 187)	0.052963295198704366
#   (0, 188)	0.007545151246576863
#
#
# ---------------- For alpha value :  0.01291549665014884  -------------
# Non zero features:  3
# The top features are:
# Sparse Coefficients:
#    (0, 0)	0.19152140971959317
#   (0, 55)	0.0899716494516959
#   (0, 187)	0.0621247615477145
#   (0, 188)	0.0066158799713399346
#
#
# ---------------- For alpha value :  0.021544346900318832  -------------
# Non zero features:  1
# The top features are:
# Sparse Coefficients:
#    (0, 0)	0.20075889410964284
#   (0, 187)	0.0761964894989779
#
#
# ---------------- For alpha value :  0.03593813663804626  -------------
# Non zero features:  1
# The top features are:
# Sparse Coefficients:
#    (0, 0)	0.1862590192825483
#   (0, 187)	0.061810934641628804
#
#
# ---------------- For alpha value :  0.05994842503189409  -------------
# Non zero features:  1
# The top features are:
# Sparse Coefficients:
#    (0, 0)	0.16207171375289645
#   (0, 187)	0.037814382442385365
#
#
# ---------------- For alpha value :  0.1  -------------
# Non zero features:  0
# The top features are:
# Sparse Coefficients:
#    (0, 0)	0.1217411906363635
# [8, 7, 7, 7, 5, 4, 2, 2, 2, 1]
#
# Leaving out fruit group :  orange
#
#
# ---------------- For alpha value :  0.001  -------------
# Non zero features:  7
# The top features are:
# Sparse Coefficients:
#    (0, 0)	0.1408215611531162
#   (0, 25)	-0.017169445642600433
#   (0, 55)	0.17853949868889443
#   (0, 180)	0.08036311540558394
#   (0, 181)	0.19273634240963913
#   (0, 186)	0.09872429487530758
#   (0, 188)	0.003879927418204193
#   (0, 191)	-0.003876511051062238
#
#
# ---------------- For alpha value :  0.0016681005372000592  -------------
# Non zero features:  7
# The top features are:
# Sparse Coefficients:
#    (0, 0)	0.14316655357636865
#   (0, 55)	0.1720672730925776
#   (0, 180)	0.07344525874213824
#   (0, 181)	0.175841806720363
#   (0, 186)	0.08615916367625932
#   (0, 187)	0.002273318118412659
#   (0, 188)	0.003251203075801091
#   (0, 191)	-0.00019611068448875112
#
#
# ---------------- For alpha value :  0.0027825594022071257  -------------
# Non zero features:  6
# The top features are:
# Sparse Coefficients:
#    (0, 0)	0.1508236856174655
#   (0, 55)	0.16392685284136535
#   (0, 180)	0.0662022068577579
#   (0, 181)	0.1311523238195536
#   (0, 186)	0.0754655645201875
#   (0, 187)	0.01189890236732224
#   (0, 188)	0.004606789910971162
#
#
# ---------------- For alpha value :  0.004641588833612777  -------------
# Non zero features:  6
# The top features are:
# Sparse Coefficients:
#    (0, 0)	0.16365929818845457
#   (0, 55)	0.15008622394182722
#   (0, 180)	0.05421258389975845
#   (0, 181)	0.055446026810990236
#   (0, 186)	0.058442140545749685
#   (0, 187)	0.028497868979743303
#   (0, 188)	0.006718794625213497
#
#
# ---------------- For alpha value :  0.007742636826811269  -------------
# Non zero features:  4
# The top features are:
# Sparse Coefficients:
#    (0, 0)	0.18124348054370823
#   (0, 55)	0.11615243220579917
#   (0, 180)	0.04462870696507759
#   (0, 187)	0.04485732475370357
#   (0, 188)	0.014255566973419018
#
#
# ---------------- For alpha value :  0.01291549665014884  -------------
# Non zero features:  3
# The top features are:
# Sparse Coefficients:
#    (0, 0)	0.19232679613042292
#   (0, 55)	0.0791070139613976
#   (0, 187)	0.0539739185414567
#   (0, 188)	0.014088297225612246
#
#
# ---------------- For alpha value :  0.021544346900318832  -------------
# Non zero features:  2
# The top features are:
# Sparse Coefficients:
#    (0, 0)	0.1993661585256003
#   (0, 187)	0.06721559621033174
#   (0, 188)	0.006012320112734464
#
#
# ---------------- For alpha value :  0.03593813663804626  -------------
# Non zero features:  1
# The top features are:
# Sparse Coefficients:
#    (0, 0)	0.18499113044021676
#   (0, 187)	0.05783221791524195
#
#
# ---------------- For alpha value :  0.05994842503189409  -------------
# Non zero features:  1
# The top features are:
# Sparse Coefficients:
#    (0, 0)	0.16101325374457637
#   (0, 187)	0.03243162858851009
#
#
# ---------------- For alpha value :  0.1  -------------
# Non zero features:  0
# The top features are:
# Sparse Coefficients:
#    (0, 0)	0.12100306223197486
# [8, 8, 7, 7, 5, 4, 3, 2, 2, 1]
#
# Leaving out fruit group :  lime
#
#
# ---------------- For alpha value :  0.001  -------------
# Non zero features:  7
# The top features are:
# Sparse Coefficients:
#    (0, 0)	0.1477366712099553
#   (0, 25)	-0.010202593879731565
#   (0, 55)	0.1655155994709029
#   (0, 180)	0.09367063457684559
#   (0, 181)	0.19283870509184423
#   (0, 186)	0.05063331780250807
#   (0, 188)	0.014765570835358502
#   (0, 191)	-0.003130471120201776
#
#
# ---------------- For alpha value :  0.0016681005372000592  -------------
# Non zero features:  6
# The top features are:
# Sparse Coefficients:
#    (0, 0)	0.1512888503602954
#   (0, 55)	0.15926639390881564
#   (0, 180)	0.08870761975587557
#   (0, 181)	0.16934829262419435
#   (0, 186)	0.03842225277282117
#   (0, 187)	0.006253474490087916
#   (0, 188)	0.011676314957195011
#
#
# ---------------- For alpha value :  0.0027825594022071257  -------------
# Non zero features:  6
# The top features are:
# Sparse Coefficients:
#    (0, 0)	0.1593054124319365
#   (0, 55)	0.15137649494794375
#   (0, 180)	0.08196483311409906
#   (0, 181)	0.1225584335535476
#   (0, 186)	0.02355377402075534
#   (0, 187)	0.01540745264501259
#   (0, 188)	0.014108676561509211
#
#
# ---------------- For alpha value :  0.004641588833612777  -------------
# Non zero features:  5
# The top features are:
# Sparse Coefficients:
#    (0, 0)	0.17267209569056857
#   (0, 55)	0.13844604196034538
#   (0, 180)	0.07041945244417475
#   (0, 181)	0.04337462319663704
#   (0, 187)	0.030991670796037544
#   (0, 188)	0.01786206414867039
#
#
# ---------------- For alpha value :  0.007742636826811269  -------------
# Non zero features:  4
# The top features are:
# Sparse Coefficients:
#    (0, 0)	0.1832139783349753
#   (0, 55)	0.12250600261111992
#   (0, 180)	0.039539810461060663
#   (0, 187)	0.04209209975069365
#   (0, 188)	0.018916122264704075
#
#
# ---------------- For alpha value :  0.01291549665014884  -------------
# Non zero features:  3
# The top features are:
# Sparse Coefficients:
#    (0, 0)	0.1938516758939032
#   (0, 55)	0.08279582339057166
#   (0, 187)	0.05010886692592442
#   (0, 188)	0.019301015633214468
#
#
# ---------------- For alpha value :  0.021544346900318832  -------------
# Non zero features:  2
# The top features are:
# Sparse Coefficients:
#    (0, 0)	0.20163966899105823
#   (0, 187)	0.06201498974383151
#   (0, 188)	0.013062941818652472
#
#
# ---------------- For alpha value :  0.03593813663804626  -------------
# Non zero features:  2
# The top features are:
# Sparse Coefficients:
#    (0, 0)	0.18691582431815748
#   (0, 187)	0.05062924793337699
#   (0, 188)	0.008358678228666724
#
#
# ---------------- For alpha value :  0.05994842503189409  -------------
# Non zero features:  2
# The top features are:
# Sparse Coefficients:
#    (0, 0)	0.16235492084548173
#   (0, 187)	0.03161784386748531
#   (0, 188)	0.000529859738280814
#
#
# ---------------- For alpha value :  0.1  -------------
# Non zero features:  0
# The top features are:
# Sparse Coefficients:
#    (0, 0)	0.12162537733542314
# [8, 7, 7, 6, 5, 4, 3, 3, 3, 1]
#
# Leaving out fruit group :  lemon
#
#
# ---------------- For alpha value :  0.001  -------------
# Non zero features:  6
# The top features are:
# Sparse Coefficients:
#    (0, 0)	0.14601654443476667
#   (0, 25)	-0.02135915535078159
#   (0, 55)	0.16992864482539616
#   (0, 180)	0.07817405160428993
#   (0, 181)	0.1771962850517384
#   (0, 186)	0.10923282770564582
#   (0, 188)	0.008643524896371576
#
#
# ---------------- For alpha value :  0.0016681005372000592  -------------
# Non zero features:  5
# The top features are:
# Sparse Coefficients:
#    (0, 0)	0.148037212157274
#   (0, 55)	0.16247487665316535
#   (0, 180)	0.07027532756290862
#   (0, 181)	0.15840693836701047
#   (0, 186)	0.09869781278674322
#   (0, 188)	0.013298329735265306
#
#
# ---------------- For alpha value :  0.0027825594022071257  -------------
# Non zero features:  6
# The top features are:
# Sparse Coefficients:
#    (0, 0)	0.15531914808798522
#   (0, 55)	0.15510509875187775
#   (0, 180)	0.06288909953893856
#   (0, 181)	0.11715485517432334
#   (0, 186)	0.0861426299861572
#   (0, 187)	0.006440522193475687
#   (0, 188)	0.01737324524549488
#
#
# ---------------- For alpha value :  0.004641588833612777  -------------
# Non zero features:  6
# The top features are:
# Sparse Coefficients:
#    (0, 0)	0.16770137847397626
#   (0, 55)	0.14203718014268318
#   (0, 180)	0.05071874515648333
#   (0, 181)	0.042412431565299606
#   (0, 186)	0.06960434256246001
#   (0, 187)	0.02277632730166019
#   (0, 188)	0.019071959057749176
#
#
# ---------------- For alpha value :  0.007742636826811269  -------------
# Non zero features:  4
# The top features are:
# Sparse Coefficients:
#    (0, 0)	0.1847211020467304
#   (0, 55)	0.10540942166762683
#   (0, 180)	0.04483122561598305
#   (0, 187)	0.03758339382764012
#   (0, 188)	0.027228024782863864
#
#
# ---------------- For alpha value :  0.01291549665014884  -------------
# Non zero features:  3
# The top features are:
# Sparse Coefficients:
#    (0, 0)	0.19567980145423206
#   (0, 55)	0.06863254805694351
#   (0, 187)	0.04683710246440086
#   (0, 188)	0.027007624685721317
#
#
# ---------------- For alpha value :  0.021544346900318832  -------------
# Non zero features:  2
# The top features are:
# Sparse Coefficients:
#    (0, 0)	0.20057573322812033
#   (0, 187)	0.057727073146245575
#   (0, 188)	0.019776039854191886
#
#
# ---------------- For alpha value :  0.03593813663804626  -------------
# Non zero features:  2
# The top features are:
# Sparse Coefficients:
#    (0, 0)	0.18629701231420856
#   (0, 187)	0.05146586716079983
#   (0, 188)	0.01162969575084089
#
#
# ---------------- For alpha value :  0.05994842503189409  -------------
# Non zero features:  1
# The top features are:
# Sparse Coefficients:
#    (0, 0)	0.16247958743844715
#   (0, 187)	0.039088605691398666
#
#
# ---------------- For alpha value :  0.1  -------------
# Non zero features:  0
# The top features are:
# Sparse Coefficients:
#    (0, 0)	0.12275288808150461
# [7, 6, 7, 7, 5, 4, 3, 3, 2, 1]

# %% [markdown]
# ### Feature #0: offset
# ### Feature #55: 20% with L=R=40 and theta = 40
# ### Feature #180: segmented area with L=R=40 with theta = 40
# ### Feature #181: categorical data looking at 20% of the image

# %%
plt.close('all')
plt.plot(alpha,np.mean(errorTrainAlpha,axis=0),'b-o',alpha,np.mean(errorTestAlpha,axis=0),'r-*')
plt.xlabel('Alpha')
plt.ylabel('Average error')
plt.title('Average error for different alpha values')
plt.legend(['Training','Test'])
plt.show()

# %%
print(len(ftTrainDict.keys()))
import statistics

numbersTrain = [] #[np.mean(ftTrainDict[key]) for key in ftTrainDict]
numbersTest = [] # [np.mean(ftTestDict[key]) for key in ftTestDict]

ftList = sorted(ftTrainDict.keys())
# print(ftTrainDict.keys())
# print([np.mean(ftTrainDict[k]) for k in ftTrainDict])
# print(ftList)
# print([np.mean(ftTrainDict[k]) for k in ftList])
for key in ftList:
    numbersTrain.append(np.mean(ftTrainDict[key]))
    numbersTest.append(np.mean(ftTestDict[key]))
fig = plt.figure(figsize=(12,7))
plt.plot(ftList,numbersTrain,'b-o',ftList, numbersTest, 'r-*')
plt.xlabel("Number of features")
plt.ylabel("Average Error")
plt.title("Average error vs Features Used")
plt.xticks([i for i in ftList])
plt.legend(['Training','Test'])
plt.show()
# Out:
# 9
