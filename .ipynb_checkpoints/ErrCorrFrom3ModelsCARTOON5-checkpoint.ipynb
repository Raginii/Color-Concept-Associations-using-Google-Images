# %% [markdown]
# ## Error and Correlation from all 3 models for 5 CARTOON images

# %%
# Initialize these:
sz = 100
filepath = 'dataCartoon50.xlsx'

# strtInd is used to keep track of beginning of the rows of a new category in the data matrix
# Copied from 01_getFeatures_cartoon_50.ipynb
strtInd = [0, 2900, 5800, 8700, 11600, 14500, 17400, 20300, 23200, 26100, 29000, 31900, 34800]

# %%
 # Include imports
import glob
from skimage.transform import resize
from skimage.io import imread, imsave, imshow
import os
import pandas as pd
import numpy as np
import skimage.color as skcolor
import matplotlib.pyplot as plt

from sklearn import datasets, linear_model
from sklearn.metrics import mean_squared_error, r2_score

# %%
colNames = ["col_"+str(i) for i in range(58)] 
allConcepts = ['mango','watermelon','honeydew','cantaloupe','grapefruit','strawberry','raspberry','blueberry','avocado','orange','lime','lemon']

# Read data
# Get the color ratings data -From file data.csv
data = pd.read_csv("data.csv",names = colNames)

# Get the LAB coordinates of colors from file Lab.csv
#colorData = pd.read_csv("Lab.csv",header=None)
colorData = pd.read_csv("Lab.csv",header=None)
colorDataRGB = pd.read_csv("RGB.csv",header=None)

# %%
df = pd.read_excel(filepath)
Q = df.as_matrix()
Q.shape
# Out:
# (34800, 187)

# %%
Xfull = np.copy(Q[:,:-1])
Yfull = np.copy(Q[:,-1])
#print(X.shape, y.shape)

# %%
startInd = [0]
X = np.empty((0,186), float)
y = np.empty((0,), float)
for t in range(len(strtInd)-1):
    strt = strtInd[t]
    end = 5*58 + strt
    X = np.r_[X, Xfull[strt:end,:] ]
    y = np.r_[y, Yfull[strt:end]]
    startInd.append(len(X))
    
tempInd = np.copy(strtInd)
strtInd = np.copy(startInd)
X.shape
print(strtInd)
# Out:
# [   0  290  580  870 1160 1450 1740 2030 2320 2610 2900 3190 3480]

# %%
# Function to computer error, correlation and rating for LOO fruit category 
# based on the features selected from Analysis (sparse regression)
from scipy import stats
        
def getRatings(minErrFeature):
    win0 = []
    win1 = []
    win2 = []
    xNew = np.column_stack([X[:,minErrFeature],y])
    correlation = []
    error = []

    # Linear Regression using Cross Validation
    # Leave one out cross validation -- strtInd holds the starting indices of set of fruit data 
    xTemp = np.copy(xNew)

    for i in range(len(strtInd)-1):
        # Leave one entire fruit group
        testFruit =  allConcepts[i]
        #print("\nLeaving out fruit group : ",allConcepts[i])
        testTemp = np.copy(xTemp[strtInd[i]:strtInd[i+1],:]) # Get all rows from the LOO group
        trainTemp = np.delete(xTemp,range(strtInd[i],strtInd[i+1]),0)
        row = len(trainTemp)
        #Training set
        X_train = np.column_stack([np.ones((row,1)), trainTemp[:,:-1]]) # add offset
        y_train = np.copy(trainTemp[:,-1])
        # Test set (hold out set)
        row2 = len(testTemp)
        X_test  = np.column_stack([np.ones((row2,1)), testTemp[:,:-1]]) #xTemp[row:tot,0:3]#
        y_test  = np.copy(testTemp[:,-1])


        # Create linear regression object
        regr = linear_model.LinearRegression(fit_intercept=False)
        # Train the model using the training sets
        regr.fit(X_train, y_train)

        # Make predictions using the testing set
        y_pred = regr.predict(X_test)
        print("Score is : %.2f" % regr.score(X_test, y_test))
        # The coefficients
        print('Coefficients: ', regr.coef_)
        #print('Intercept: \n', regr.intercept_)
        # The mean squared error
        print("\nMean squared error: %.4f"
              % mean_squared_error(y_test, y_pred))
        # Explained variance score: 1 is perfect prediction
        print('Variance score: %.2f' % r2_score(y_test, y_pred))

        ############## For test purposes - Average prediction over all Images of LOO group ############
        totalTestImages = y_pred.size/58  #58N rows -> every image has 58 rows of data
        avg_pred = [np.sum([y_pred[p] for p in range(q,y_pred.size,58)])/totalTestImages for q in range(58)]

        # For Pearson correlation coefficient and the p-value (between avg_pred and true rating for fruit group)
        trueRating = np.copy(y_test[0:58])

        sqErr = np.sum(pow(avg_pred - trueRating,2))
        print("The true squared error (in color ratings) for left out fruit",testFruit,"is: %.4f" % sqErr)

        corrCoeff, pVal = stats.pearsonr(avg_pred, trueRating)
        print("\nPearson’s correlation coefficient (between true ratings and avg predicted ratings) is %.4f" %corrCoeff)
        print("p-value %.4f" %pVal)

        error.append(sqErr)
        correlation.append(corrCoeff)
        win0.append(corrCoeff) # saves correlation for test fruit
        win1.append(trueRating) # saves true rating for test fruit
        win2.append(avg_pred)   # saves avg predicted rating for test fruit
        # Plot average color rating over all test images.
        fig= plt.figure(figsize=(10,3))
        barPlot = plt.bar(range(1,59), avg_pred,color = colorDataRGB.values)
        plt.ylabel('Ratings')
        plt.xlabel('Colors')
        plt.title('Predicted color ratings for Fruit Group : %s' %testFruit)
        plt.xticks([i for i in range(1,59,3)],[i for i in range(1,59,3)])
        plt.ylim(0,1)
        plt.show()

        fig= plt.figure(figsize=(10,3))
        barPlot = plt.bar(range(1,59), trueRating,color = colorDataRGB.values)
        plt.ylabel('Ratings')
        plt.xlabel('Colors')
        plt.title('True color ratings for Fruit Group : %s' %testFruit)
        plt.xticks([i for i in range(1,59,3)],[i for i in range(1,59,3)])
        plt.ylim(0,1)
        plt.show()

        # Scatter plot
        fig2 = plt.figure(figsize=(7,7))
        plt.scatter(trueRating,avg_pred,c=colorDataRGB.values,marker = 'o',linewidths=2.5)
        plt.ylabel('Predicted Ratings')
        plt.xlabel('Subject Ratings')
        plt.title('Scatter plot of color ratings for : %s' %testFruit)
        plt.axis('equal')
        plt.xlim(0,1)
        plt.ylim(0,1)
        plt.show() 
    return error, correlation, win0, win1, win2

# %% [markdown]
# # Regression on top 3 spherical features

# %%
# Sparse features from Analysis I
minErrFeature1 = (4, 24, 29)
errSph, corrSph, win0_m1, win1_m1, win2_m1  = getRatings(minErrFeature1)
# Out:
# Score is : 0.48
# Coefficients:  [ 0.16268673  0.51593677 -0.19951402  0.09904677]
#
# Mean squared error: 0.0175
# Variance score: 0.48
# The true squared error (in color ratings) for left out fruit mango is: 0.8571
#
# Pearson’s correlation coefficient (between true ratings and avg predicted ratings) is 0.8064
# p-value 0.0000
# Score is : 0.07
# Coefficients:  [ 0.1561642   0.52962938 -0.19958222  0.10370568]
#
# Mean squared error: 0.0341
# Variance score: 0.07
# The true squared error (in color ratings) for left out fruit watermelon is: 1.6956
#
# Pearson’s correlation coefficient (between true ratings and avg predicted ratings) is 0.5752
# p-value 0.0000
# Score is : 0.36
# Coefficients:  [ 0.16138662  0.52146982 -0.18529897  0.10340296]
#
# Mean squared error: 0.0128
# Variance score: 0.36
# The true squared error (in color ratings) for left out fruit honeydew is: 0.6780
#
# Pearson’s correlation coefficient (between true ratings and avg predicted ratings) is 0.6569
# p-value 0.0000
# Score is : 0.57
# Coefficients:  [ 0.16348025  0.52259874 -0.199711    0.09231608]
#
# Mean squared error: 0.0134
# Variance score: 0.57
# The true squared error (in color ratings) for left out fruit cantaloupe is: 0.6166
#
# Pearson’s correlation coefficient (between true ratings and avg predicted ratings) is 0.8580
# p-value 0.0000
# Score is : 0.31
# Coefficients:  [ 0.1601339   0.568971   -0.20007169  0.05204736]
#
# Mean squared error: 0.0168
# Variance score: 0.31
# The true squared error (in color ratings) for left out fruit grapefruit is: 0.6871
#
# Pearson’s correlation coefficient (between true ratings and avg predicted ratings) is 0.8079
# p-value 0.0000
# Score is : 0.25
# Coefficients:  [ 0.15977452  0.54157948 -0.21122192  0.09636427]
#
# Mean squared error: 0.0206
# Variance score: 0.25
# The true squared error (in color ratings) for left out fruit strawberry is: 1.0931
#
# Pearson’s correlation coefficient (between true ratings and avg predicted ratings) is 0.5720
# p-value 0.0000
# Score is : 0.31
# Coefficients:  [ 0.1609007   0.52356489 -0.20222274  0.11040573]
#
# Mean squared error: 0.0164
# Variance score: 0.31
# The true squared error (in color ratings) for left out fruit raspberry is: 0.7313
#
# Pearson’s correlation coefficient (between true ratings and avg predicted ratings) is 0.6962
# p-value 0.0000
# Score is : 0.36
# Coefficients:  [ 0.16395838  0.53531058 -0.22204353  0.10595499]
#
# Mean squared error: 0.0272
# Variance score: 0.36
# The true squared error (in color ratings) for left out fruit blueberry is: 1.3287
#
# Pearson’s correlation coefficient (between true ratings and avg predicted ratings) is 0.6905
# p-value 0.0000
# Score is : 0.11
# Coefficients:  [ 0.16255966  0.54487968 -0.19408979  0.08312043]
#
# Mean squared error: 0.0317
# Variance score: 0.11
# The true squared error (in color ratings) for left out fruit avocado is: 1.6140
#
# Pearson’s correlation coefficient (between true ratings and avg predicted ratings) is 0.5018
# p-value 0.0001
# Score is : 0.46
# Coefficients:  [ 0.16340297  0.54265673 -0.21354934  0.07806854]
#
# Mean squared error: 0.0201
# Variance score: 0.46
# The true squared error (in color ratings) for left out fruit orange is: 0.9101
#
# Pearson’s correlation coefficient (between true ratings and avg predicted ratings) is 0.8162
# p-value 0.0000
# Score is : 0.53
# Coefficients:  [ 0.16610242  0.48911982 -0.19377723  0.11741962]
#
# Mean squared error: 0.0207
# Variance score: 0.53
# The true squared error (in color ratings) for left out fruit lime is: 0.9911
#
# Pearson’s correlation coefficient (between true ratings and avg predicted ratings) is 0.8888
# p-value 0.0000
# Score is : 0.57
# Coefficients:  [ 0.16616347  0.51757257 -0.20945271  0.09519651]
#
# Mean squared error: 0.0112
# Variance score: 0.57
# The true squared error (in color ratings) for left out fruit lemon is: 0.5685
#
# Pearson’s correlation coefficient (between true ratings and avg predicted ratings) is 0.8742
# p-value 0.0000

# %%
errSph
# Out:
# [0.8571062602601869,
#  1.6956297122875734,
#  0.6780284669207483,
#  0.6166108459940167,
#  0.6871023675441409,
#  1.093095300719259,
#  0.7313316237394099,
#  1.3286639092325858,
#  1.6140061540714812,
#  0.9101146545464621,
#  0.9911168766442245,
#  0.5684812215686531]

# %%
corrSph
# Out:
# [0.8063992836173391,
#  0.5752215245461727,
#  0.6568523679939798,
#  0.857992452908025,
#  0.8078830265299508,
#  0.5719721372538653,
#  0.6961756921747033,
#  0.6904955327887263,
#  0.5017645127500642,
#  0.81616200955442,
#  0.8888402281010183,
#  0.8741972051497079]

# %% [markdown]
# # Regression on top 3 spherical + cyindrical features

# %%
# Sparse features from Analysis II
minErrFeature2 = (54, 78, 179)
errSphCyl, corrSphCyl,win0_m2, win1_m2, win2_m2 = getRatings(minErrFeature2)
# Out:
# Score is : 0.56
# Coefficients:  [0.13629578 0.2713744  0.1696913  0.04086192]
#
# Mean squared error: 0.0149
# Variance score: 0.56
# The true squared error (in color ratings) for left out fruit mango is: 0.7437
#
# Pearson’s correlation coefficient (between true ratings and avg predicted ratings) is 0.8380
# p-value 0.0000
# Score is : 0.11
# Coefficients:  [0.13006635 0.30381651 0.14036474 0.04180366]
#
# Mean squared error: 0.0325
# Variance score: 0.11
# The true squared error (in color ratings) for left out fruit watermelon is: 1.6823
#
# Pearson’s correlation coefficient (between true ratings and avg predicted ratings) is 0.6092
# p-value 0.0000
# Score is : 0.56
# Coefficients:  [0.13521845 0.28577506 0.17830277 0.0293897 ]
#
# Mean squared error: 0.0089
# Variance score: 0.56
# The true squared error (in color ratings) for left out fruit honeydew is: 0.4704
#
# Pearson’s correlation coefficient (between true ratings and avg predicted ratings) is 0.7720
# p-value 0.0000
# Score is : 0.61
# Coefficients:  [0.13646473 0.28477978 0.18059287 0.01688186]
#
# Mean squared error: 0.0121
# Variance score: 0.61
# The true squared error (in color ratings) for left out fruit cantaloupe is: 0.5945
#
# Pearson’s correlation coefficient (between true ratings and avg predicted ratings) is 0.8616
# p-value 0.0000
# Score is : 0.39
# Coefficients:  [ 0.13381554  0.32672271  0.19704922 -0.03395834]
#
# Mean squared error: 0.0149
# Variance score: 0.39
# The true squared error (in color ratings) for left out fruit grapefruit is: 0.6714
#
# Pearson’s correlation coefficient (between true ratings and avg predicted ratings) is 0.7688
# p-value 0.0000
# Score is : 0.17
# Coefficients:  [0.13301635 0.32521182 0.15089944 0.02068758]
#
# Mean squared error: 0.0226
# Variance score: 0.17
# The true squared error (in color ratings) for left out fruit strawberry is: 1.1639
#
# Pearson’s correlation coefficient (between true ratings and avg predicted ratings) is 0.5303
# p-value 0.0000
# Score is : 0.28
# Coefficients:  [0.13451183 0.29588593 0.16199643 0.03995712]
#
# Mean squared error: 0.0172
# Variance score: 0.28
# The true squared error (in color ratings) for left out fruit raspberry is: 0.7571
#
# Pearson’s correlation coefficient (between true ratings and avg predicted ratings) is 0.6789
# p-value 0.0000
# Score is : 0.39
# Coefficients:  [0.13679149 0.30179745 0.15225651 0.03142636]
#
# Mean squared error: 0.0258
# Variance score: 0.39
# The true squared error (in color ratings) for left out fruit blueberry is: 1.3430
#
# Pearson’s correlation coefficient (between true ratings and avg predicted ratings) is 0.6902
# p-value 0.0000
# Score is : 0.18
# Coefficients:  [0.13560051 0.30926546 0.16747897 0.01960337]
#
# Mean squared error: 0.0296
# Variance score: 0.18
# The true squared error (in color ratings) for left out fruit avocado is: 1.5279
#
# Pearson’s correlation coefficient (between true ratings and avg predicted ratings) is 0.5257
# p-value 0.0000
# Score is : 0.43
# Coefficients:  [0.13585957 0.30549277 0.1733914  0.01346124]
#
# Mean squared error: 0.0213
# Variance score: 0.43
# The true squared error (in color ratings) for left out fruit orange is: 0.9254
#
# Pearson’s correlation coefficient (between true ratings and avg predicted ratings) is 0.7800
# p-value 0.0000
# Score is : 0.55
# Coefficients:  [0.13897062 0.25249503 0.16645161 0.05742424]
#
# Mean squared error: 0.0198
# Variance score: 0.55
# The true squared error (in color ratings) for left out fruit lime is: 0.9930
#
# Pearson’s correlation coefficient (between true ratings and avg predicted ratings) is 0.8617
# p-value 0.0000
# Score is : 0.61
# Coefficients:  [0.13856575 0.29500648 0.15880351 0.02676879]
#
# Mean squared error: 0.0101
# Variance score: 0.61
# The true squared error (in color ratings) for left out fruit lemon is: 0.4896
#
# Pearson’s correlation coefficient (between true ratings and avg predicted ratings) is 0.8624
# p-value 0.0000

# %% [markdown]
# # Regression on top 3 Spherical + Cylindrical + Categorical

# %%
# Sparse features from Analysis III
minErrFeature3 = (54, 179, 180)
errSphCylCat, corrSphCylCat, win0_m3, win1_m3, win2_m3 = getRatings(minErrFeature3)
# Out:
# Score is : 0.45
# Coefficients:  [0.13105583 0.15145629 0.11646797 0.3870435 ]
#
# Mean squared error: 0.0185
# Variance score: 0.45
# The true squared error (in color ratings) for left out fruit mango is: 0.8776
#
# Pearson’s correlation coefficient (between true ratings and avg predicted ratings) is 0.7840
# p-value 0.0000
# Score is : 0.13
# Coefficients:  [0.12438164 0.19739257 0.09236522 0.3701704 ]
#
# Mean squared error: 0.0318
# Variance score: 0.13
# The true squared error (in color ratings) for left out fruit watermelon is: 1.4992
#
# Pearson’s correlation coefficient (between true ratings and avg predicted ratings) is 0.7034
# p-value 0.0000
# Score is : 0.69
# Coefficients:  [0.13199755 0.20691233 0.07003658 0.38304313]
#
# Mean squared error: 0.0062
# Variance score: 0.69
# The true squared error (in color ratings) for left out fruit honeydew is: 0.2956
#
# Pearson’s correlation coefficient (between true ratings and avg predicted ratings) is 0.8761
# p-value 0.0000
# Score is : 0.60
# Coefficients:  [0.13156183 0.19061078 0.07994465 0.37711654]
#
# Mean squared error: 0.0125
# Variance score: 0.60
# The true squared error (in color ratings) for left out fruit cantaloupe is: 0.4660
#
# Pearson’s correlation coefficient (between true ratings and avg predicted ratings) is 0.9251
# p-value 0.0000
# Score is : 0.39
# Coefficients:  [0.12798829 0.2314564  0.04498401 0.37420946]
#
# Mean squared error: 0.0149
# Variance score: 0.39
# The true squared error (in color ratings) for left out fruit grapefruit is: 0.6923
#
# Pearson’s correlation coefficient (between true ratings and avg predicted ratings) is 0.7745
# p-value 0.0000
# Score is : 0.31
# Coefficients:  [0.12766187 0.22128436 0.07758347 0.3592753 ]
#
# Mean squared error: 0.0188
# Variance score: 0.31
# The true squared error (in color ratings) for left out fruit strawberry is: 0.9769
#
# Pearson’s correlation coefficient (between true ratings and avg predicted ratings) is 0.6280
# p-value 0.0000
# Score is : 0.31
# Coefficients:  [0.12929437 0.19061336 0.09854972 0.37144729]
#
# Mean squared error: 0.0165
# Variance score: 0.31
# The true squared error (in color ratings) for left out fruit raspberry is: 0.7541
#
# Pearson’s correlation coefficient (between true ratings and avg predicted ratings) is 0.6778
# p-value 0.0000
# Score is : 0.70
# Coefficients:  [0.13368655 0.21513827 0.08194944 0.34371134]
#
# Mean squared error: 0.0126
# Variance score: 0.70
# The true squared error (in color ratings) for left out fruit blueberry is: 0.6393
#
# Pearson’s correlation coefficient (between true ratings and avg predicted ratings) is 0.8909
# p-value 0.0000
# Score is : 0.44
# Coefficients:  [0.13196759 0.21868004 0.08287794 0.34845732]
#
# Mean squared error: 0.0201
# Variance score: 0.44
# The true squared error (in color ratings) for left out fruit avocado is: 0.9161
#
# Pearson’s correlation coefficient (between true ratings and avg predicted ratings) is 0.7816
# p-value 0.0000
# Score is : 0.62
# Coefficients:  [0.13142008 0.21903601 0.07049861 0.35490851]
#
# Mean squared error: 0.0144
# Variance score: 0.62
# The true squared error (in color ratings) for left out fruit orange is: 0.5877
#
# Pearson’s correlation coefficient (between true ratings and avg predicted ratings) is 0.8792
# p-value 0.0000
# Score is : 0.77
# Coefficients:  [0.13439002 0.18118579 0.1076037  0.35234145]
#
# Mean squared error: 0.0099
# Variance score: 0.77
# The true squared error (in color ratings) for left out fruit lime is: 0.4733
#
# Pearson’s correlation coefficient (between true ratings and avg predicted ratings) is 0.9316
# p-value 0.0000
# Score is : 0.73
# Coefficients:  [0.13381685 0.19119736 0.08604323 0.36405631]
#
# Mean squared error: 0.0071
# Variance score: 0.73
# The true squared error (in color ratings) for left out fruit lemon is: 0.3458
#
# Pearson’s correlation coefficient (between true ratings and avg predicted ratings) is 0.9183
# p-value 0.0000

# %%
temp  = errSph
indices = np.argsort(temp)
label = [allConcepts[i] for i in indices]

barWidth = 1.2
r1 = range(1,121,10)
r2 = [x + barWidth for x in r1]
r3 = [x + 2*barWidth for x in r1]

#t.bar(r1, bars1, width = barWidth, color = 'blue', edgecolor = 'black', yerr=yer1, capsize=7, label='poacee')
fig = plt.figure(figsize=(15,8))
plt.bar(r1,sorted(errSph),width = barWidth, color = 'cyan', edgecolor = 'black',label='Spherical')
plt.bar(r2,[errSphCyl[t] for t in indices],width = barWidth, color = 'orange', edgecolor = 'black',label='Spherical + Cylindrical')
plt.bar(r3,[errSphCylCat[t] for t in indices],width = barWidth, color = 'violet', edgecolor = 'black',label='Spherical + Cylindrical + Categorical')
plt.xticks(range(1,121,10),label)
plt.title("Squared Error")
plt.ylabel('Error')
plt.legend()
#plt.savefig('ErrWithIncreasingRadial.pdf')
plt.show()

# %%
temp  = corrSph
indices = np.argsort(temp)
label = [allConcepts[i] for i in indices]

barWidth = 1.2
r1 = range(1,121,10)
r2 = [x + barWidth for x in r1]
r3 = [x + 2*barWidth for x in r1]
plt.close('all')
#t.bar(r1, bars1, width = barWidth, color = 'blue', edgecolor = 'black', yerr=yer1, capsize=7, label='poacee')
fig = plt.figure(figsize=(15,8))
plt.bar(r1,sorted(corrSph),width = barWidth, color = 'cyan', edgecolor = 'black',label='Spherical')
plt.bar(r2,[corrSphCyl[t] for t in indices],width = barWidth, color = 'orange', edgecolor = 'black',label='Spherical + Cylindrical')
plt.bar(r3,[corrSphCylCat[t] for t in indices],width = barWidth, color = 'violet', edgecolor = 'black',label='Spherical + Cylindrical + Categorical')
plt.xticks(range(1,121,10),label)
plt.title("Correlation")
plt.ylabel('Error')
plt.legend()
#plt.savefig('CorrWithIncreasingRadial.eps')
plt.show()

# %%
# # For plots of correlations
# err, corr, win0, win1, win2 = getRatings(minErrFeature3, True)

# %% [markdown]
# # Figure2: Scatter plots for the best model

# %%
import matplotlib as mpl
mpl.rcParams.update({'font.size': 9})
def createScatterPlots(indices, win0, win1, win2,model_num):
    print("----------------------- Creating plots for Model ---------------",model_num)
    # print(indices)
    # print(win0)
    
    k = 1
    plt.close('all')

    plt.subplots(3,4,figsize=(10,10))
    for i in range(len(indices)-1,-1,-1):
        # Scatter plot

        arg = indices[i]
        trueRating = win1[arg]
        avg_pred = win2[arg]

        ax = plt.subplot(3,4,k,aspect='equal') #plt.figure(figsize=(7,7))
        #ax = f.add_subplot(3,4,k)
        plt.scatter(trueRating,avg_pred,c=colorDataRGB.values,marker = 'o',linewidths=2.5)
        if k == 1 or k == 5 or k == 9:
            plt.ylabel('Mean Predicted Rating')
        plt.xlabel('Mean Rating')
        s = allConcepts[arg]+"( %.2f )" %win0[arg]
        #print(s)
        plt.title(s)
        plt.xlim(0,1)
        plt.ylim(0,1)
        plt.yticks([0,0.5,1])
        plt.xticks([0,0.5,1])
        plt.tick_params(direction='in')
        plt.plot(np.unique(trueRating), np.poly1d(np.polyfit(trueRating, avg_pred, 1))(np.unique(trueRating)),'k--')
        k = k+1
    #plotName = "ScatterPlot_Model_"+str(model_num)+".pdf"
    #plt.savefig(plotName)
    plt.show()

# %%
indices = np.argsort(win0_m1) # Want in the order of model 1 correlations
createScatterPlots(indices, win0_m1, win1_m1, win2_m1,1)
createScatterPlots(indices, win0_m2, win1_m2, win2_m2,2)
createScatterPlots(indices,win0_m3, win1_m3, win2_m3,3)
# Out:
# ----------------------- Creating plots for Model --------------- 1
# ----------------------- Creating plots for Model --------------- 2
# ----------------------- Creating plots for Model --------------- 3

# %%
# indices = np.argsort(win0_m3)
# print(indices)
# print(win0_m3)

# %%
# k = 1
# plt.close('all')
# import matplotlib as mpl
# mpl.rcParams.update({'font.size': 9})
# plt.subplots(3,4,figsize=(10,10))
# for i in range(len(indices)-1,-1,-1):
#     # Scatter plot
    
#     arg = indices[i]
#     trueRating = win1_m3[arg]
#     avg_pred = win2_m3[arg]
    
#     ax = plt.subplot(3,4,k,aspect='equal') #plt.figure(figsize=(7,7))
#     #ax = f.add_subplot(3,4,k)
#     plt.scatter(trueRating,avg_pred,c=colorDataRGB.values,marker = 'o',linewidths=2.5)
#     if k == 1 or k == 5 or k == 9:
#         plt.ylabel('Mean Predicted Rating')
#     plt.xlabel('Mean Rating')
#     s = allConcepts[arg]+"( %.2f )" %win0_m3[arg]
#     #print(s)
#     plt.title(s)
#     plt.xlim(0,1)
#     plt.ylim(0,1)
#     plt.yticks([0,0.5,1])
#     plt.xticks([0,0.5,1])
#     plt.tick_params(direction='in')
#     plt.plot(np.unique(trueRating), np.poly1d(np.polyfit(trueRating, avg_pred, 1))(np.unique(trueRating)),'k--')
#     k = k+1
# #plt.savefig('ScatterPlotBestModel.pdf')
# plt.show()

# %%
cor_m3,_ = stats.pearsonr(np.array(win2_m3).flatten(), np.array(win1_m3).flatten())
cor_m2,_ = stats.pearsonr(np.array(win2_m2).flatten(), np.array(win1_m2).flatten())
cor_m1,_ = stats.pearsonr(np.array(win2_m1).flatten(), np.array(win1_m1).flatten())

# %%
print("For CARTOON 5")
print("model 1:", cor_m1)
print("model 2:",cor_m2)
print("model :3",cor_m3)
# Out:
# For CARTOON 5
# model 1: 0.713415351736103
# model 2: 0.7173524698027135
# model :3 0.7987607856897588

# %%
barWidth = 0.5
plt.bar(range(1,4),[cor_m1, cor_m2, cor_m3], width = barWidth)
plt.xticks(range(1,4),['M1','M2','M3'])
plt.title("Correlation for CARTOON Images (#: 5 Images)")
plt.ylabel('Correlation')
plt.show()
